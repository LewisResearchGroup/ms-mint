# %%
# For custom plots
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # Run mint in a single command

# %%
from ms_mint.notebook import Mint

mint = Mint(verbose=True)\
    .load_targets('input/targets.csv')\
    .load_files('/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/**/*mz*ML')\
    .load_metadata('input/metadata.csv')\
    .run()
# Out:
# Mint version: v0.3.1+7.g6fded3f.dirty
#
# input/targets.csv
#
# Set targets to:
#                mz_mean  mz_width       rt  rt_min  rt_max rt_unit  intensity_threshold target_filename
# peak_label
# Arabitol    151.06050        10  295.500   277.0   315.0       s                    0     targets.csv
# Mevalonate  147.06570        10  180.000   100.0   266.0       s                    0     targets.csv
# Nicotinate  122.02455        10  183.204   163.0   228.0       s                    0     targets.csv
# Succinate   117.01905        10  122.634   122.2   150.0       s                    0     targets.csv
# Urocanate   137.03540        10  264.900   240.0   290.0       s                    0     targets.csv
# Xanthine    151.02585        10  250.000   208.0   290.8       s                    0     targets.csv
#
# Set files to:
# /data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/CA_B1.mzXML
# /data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/SA_B3.mzML
# /data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/EC_B1.mzXML
# /data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/EC_B3.mzXML
# /data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/CA_B3.mzXML
# /data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/SA_B1.mzML
# /data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/CA_B2.mzXML
# /data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/CA_B4.mzXML
# /data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/EC_B2.mzXML
# /data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/EC_B4.mzXML
# /data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/SA_B2.mzML
# /data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/SA_B4.mzML
#
# Run MINT with 12 processes:
# Total runtime: 3.22s
# Runtime per file: 0.27s
# Runtime per peak (6): 0.04s
#
# Results:                                               ms_file ms_file_label  \
# 0   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 1   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 2   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 3   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 4   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# ..                                                ...           ...
# 67  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 68  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 69  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 70  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 71  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
#
#     peak_label    mz_mean  mz_width       rt  rt_min  rt_max rt_unit  \
# 0     Arabitol  151.06050        10  295.500   277.0   315.0       s
# 1   Mevalonate  147.06570        10  180.000   100.0   266.0       s
# 2   Nicotinate  122.02455        10  183.204   163.0   228.0       s
# 3    Succinate  117.01905        10  122.634   122.2   150.0       s
# 4    Urocanate  137.03540        10  264.900   240.0   290.0       s
# ..         ...        ...       ...      ...     ...     ...     ...
# 67  Mevalonate  147.06570        10  180.000   100.0   266.0       s
# 68  Nicotinate  122.02455        10  183.204   163.0   228.0       s
# 69   Succinate  117.01905        10  122.634   122.2   150.0       s
# 70   Urocanate  137.03540        10  264.900   240.0   290.0       s
# 71    Xanthine  151.02585        10  250.000   208.0   290.8       s
#
#     intensity_threshold  ...      peak_mean  peak_delta_int  \
# 0                     0  ...   24557.864407          2602.0
# 1                     0  ...     509.590909            18.0
# 2                     0  ...    3177.058824            88.0
# 3                     0  ...    7329.189189         12906.0
# 4                     0  ...    1765.729167          3260.0
# ..                  ...  ...            ...             ...
# 67                    0  ...   52368.484305          2068.0
# 68                    0  ...   24320.962025          1743.0
# 69                    0  ...  752644.750000       2877737.0
# 70                    0  ...    6359.886792          3155.0
# 71                    0  ...    2002.225352          2948.0
#
#                                         peak_shape_rt  \
# 0   277.1,277.81,278.51,279.18,279.86,280.55,281.2...
# 1   100.33,105.63,106.39,114.73,115.49,123.83,125....
# 2   173.88,176.91,178.43,179.18,179.94,180.7,181.4...
# 3   122.32,123.07,123.83,124.59,125.35,126.11,126....
# 4   240.2,240.95,242.47,243.23,243.99,244.74,245.5...
# ..                                                ...
# 67  100.74,101.5,102.26,103.02,103.77,104.53,105.2...
# 68  168.98,169.74,171.26,172.02,172.77,173.53,174....
# 69  122.73,123.49,124.25,125.01,125.76,126.52,127....
# 70  240.71,241.47,242.23,242.97,243.7,244.45,245.2...
# 71  208.19,208.9,209.61,210.32,211.03,211.74,212.4...
#
#                                        peak_shape_int  peak_mass_diff_25pc  \
# 0   2422,2798,5192,6006,9870,14188,20467,35327,419...             2.330528
# 1   422,333,377,475,479,444,428,548,562,721,511,12...             1.689628
# 2   647,811,698,455,1794,2279,3196,2557,3740,4891,...            -0.801400
# 3   17542,14418,14203,13654,13245,9973,8776,11262,...             0.005112
# 4   340,547,926,532,1940,767,905,2303,585,1668,424...            -0.553896
# ..                                                ...                  ...
# 67  3328,2942,2681,3101,5945,7104,7598,10937,22360...             4.283501
# 68  435,645,2091,3105,4858,7611,12579,15085,23960,...             2.012154
# 69  2903296,2716713,2841678,2719333,2649623,238784...             2.547829
# 70  6593,5143,5757,6258,6384,6732,4902,4705,3539,3...             1.784439
# 71  3807,4755,4504,4662,3813,3681,2260,614,665,133...             2.060534
#
#     peak_mass_diff_50pc  peak_mass_diff_75pc  peak_score  total_intensity  \
# 0              2.532551             2.633562           0      25525758921
# 1              2.104648             2.208403           0      25525758921
# 2             -0.676354            -0.488783           0      25525758921
# 3              0.070309             0.265903           0      25525758921
# 4             -0.331197            -0.192011           0      25525758921
# ..                  ...                  ...         ...              ...
# 67             4.283501             4.491011           0      35863205487
# 68             2.137201             2.262248           0      35863205487
# 69             2.678225             2.743423           0      35863205487
# 70             2.007137             2.118486           0      35863205487
# 71             2.212085             2.414154           0      35863205487
#
#     ms_file_size_MB
# 0         12.731823
# 1         12.731823
# 2         12.731823
# 3         12.731823
# 4         12.731823
# ..              ...
# 67        16.030061
# 68        16.030061
# 69        16.030061
# 70        16.030061
# 71        16.030061
#
# [72 rows x 28 columns]

# %% [markdown]
# ## Show files in queue

# %%
mint.ms_files
# Out:
# ['/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/CA_B1.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/SA_B3.mzML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/EC_B1.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/EC_B3.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/CA_B3.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/SA_B1.mzML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/CA_B2.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/CA_B4.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/EC_B2.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/EC_B4.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/SA_B2.mzML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/SA_B4.mzML']

# %% [markdown]
# ## Show target-list

# %%
mint.targets
# Out:
#               mz_mean  mz_width       rt  rt_min  rt_max rt_unit  \
# peak_label
# Arabitol    151.06050        10  295.500   277.0   315.0       s
# Mevalonate  147.06570        10  180.000   100.0   266.0       s
# Nicotinate  122.02455        10  183.204   163.0   228.0       s
# Succinate   117.01905        10  122.634   122.2   150.0       s
# Urocanate   137.03540        10  264.900   240.0   290.0       s
# Xanthine    151.02585        10  250.000   208.0   290.8       s
#
#             intensity_threshold target_filename
# peak_label
# Arabitol                      0     targets.csv
# Mevalonate                    0     targets.csv
# Nicotinate                    0     targets.csv
# Succinate                     0     targets.csv
# Urocanate                     0     targets.csv
# Xanthine                      0     targets.csv

# %% [markdown]
# ## Show metadata

# %%
mint.meta
# Out:
#               label  group  batch  sample_type  run_order  plate  plate_row  \
# ms_file_label
# CA_B1            CA    NaN      1          NaN          1    NaN        NaN
# CA_B2            CA    NaN      2          NaN          4    NaN        NaN
# CA_B3            CA    NaN      3          NaN          7    NaN        NaN
# CA_B4            CA    NaN      4          NaN         10    NaN        NaN
# EC_B1            EC    NaN      1          NaN          2    NaN        NaN
# EC_B2            EC    NaN      2          NaN          5    NaN        NaN
# EC_B3            EC    NaN      3          NaN          8    NaN        NaN
# EC_B4            EC    NaN      4          NaN         11    NaN        NaN
# SA_B1            SA    NaN      1          NaN          3    NaN        NaN
# SA_B2            SA    NaN      2          NaN          6    NaN        NaN
# SA_B3            SA    NaN      3          NaN          9    NaN        NaN
# SA_B4            SA    NaN      4          NaN         12    NaN        NaN
#
#                plate_col  lc_column polarity
# ms_file_label
# CA_B1                NaN        NaN        -
# CA_B2                NaN        NaN        -
# CA_B3                NaN        NaN        -
# CA_B4                NaN        NaN        -
# EC_B1                NaN        NaN        -
# EC_B2                NaN        NaN        -
# EC_B3                NaN        NaN        -
# EC_B4                NaN        NaN        -
# SA_B1                NaN        NaN        -
# SA_B2                NaN        NaN        -
# SA_B3                NaN        NaN        -
# SA_B4                NaN        NaN        -

# %% [markdown]
# ## Show results

# %%
mint.results
# Out:
#                                               ms_file ms_file_label  \
# 0   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 1   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 2   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 3   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 4   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# ..                                                ...           ...
# 67  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 68  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 69  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 70  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 71  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
#
#     peak_label    mz_mean  mz_width       rt  rt_min  rt_max rt_unit  \
# 0     Arabitol  151.06050        10  295.500   277.0   315.0       s
# 1   Mevalonate  147.06570        10  180.000   100.0   266.0       s
# 2   Nicotinate  122.02455        10  183.204   163.0   228.0       s
# 3    Succinate  117.01905        10  122.634   122.2   150.0       s
# 4    Urocanate  137.03540        10  264.900   240.0   290.0       s
# ..         ...        ...       ...      ...     ...     ...     ...
# 67  Mevalonate  147.06570        10  180.000   100.0   266.0       s
# 68  Nicotinate  122.02455        10  183.204   163.0   228.0       s
# 69   Succinate  117.01905        10  122.634   122.2   150.0       s
# 70   Urocanate  137.03540        10  264.900   240.0   290.0       s
# 71    Xanthine  151.02585        10  250.000   208.0   290.8       s
#
#     intensity_threshold  ...      peak_mean  peak_delta_int  \
# 0                     0  ...   24557.864407          2602.0
# 1                     0  ...     509.590909            18.0
# 2                     0  ...    3177.058824            88.0
# 3                     0  ...    7329.189189         12906.0
# 4                     0  ...    1765.729167          3260.0
# ..                  ...  ...            ...             ...
# 67                    0  ...   52368.484305          2068.0
# 68                    0  ...   24320.962025          1743.0
# 69                    0  ...  752644.750000       2877737.0
# 70                    0  ...    6359.886792          3155.0
# 71                    0  ...    2002.225352          2948.0
#
#                                         peak_shape_rt  \
# 0   277.1,277.81,278.51,279.18,279.86,280.55,281.2...
# 1   100.33,105.63,106.39,114.73,115.49,123.83,125....
# 2   173.88,176.91,178.43,179.18,179.94,180.7,181.4...
# 3   122.32,123.07,123.83,124.59,125.35,126.11,126....
# 4   240.2,240.95,242.47,243.23,243.99,244.74,245.5...
# ..                                                ...
# 67  100.74,101.5,102.26,103.02,103.77,104.53,105.2...
# 68  168.98,169.74,171.26,172.02,172.77,173.53,174....
# 69  122.73,123.49,124.25,125.01,125.76,126.52,127....
# 70  240.71,241.47,242.23,242.97,243.7,244.45,245.2...
# 71  208.19,208.9,209.61,210.32,211.03,211.74,212.4...
#
#                                        peak_shape_int  peak_mass_diff_25pc  \
# 0   2422,2798,5192,6006,9870,14188,20467,35327,419...             2.330528
# 1   422,333,377,475,479,444,428,548,562,721,511,12...             1.689628
# 2   647,811,698,455,1794,2279,3196,2557,3740,4891,...            -0.801400
# 3   17542,14418,14203,13654,13245,9973,8776,11262,...             0.005112
# 4   340,547,926,532,1940,767,905,2303,585,1668,424...            -0.553896
# ..                                                ...                  ...
# 67  3328,2942,2681,3101,5945,7104,7598,10937,22360...             4.283501
# 68  435,645,2091,3105,4858,7611,12579,15085,23960,...             2.012154
# 69  2903296,2716713,2841678,2719333,2649623,238784...             2.547829
# 70  6593,5143,5757,6258,6384,6732,4902,4705,3539,3...             1.784439
# 71  3807,4755,4504,4662,3813,3681,2260,614,665,133...             2.060534
#
#     peak_mass_diff_50pc  peak_mass_diff_75pc  peak_score  total_intensity  \
# 0              2.532551             2.633562           0      25525758921
# 1              2.104648             2.208403           0      25525758921
# 2             -0.676354            -0.488783           0      25525758921
# 3              0.070309             0.265903           0      25525758921
# 4             -0.331197            -0.192011           0      25525758921
# ..                  ...                  ...         ...              ...
# 67             4.283501             4.491011           0      35863205487
# 68             2.137201             2.262248           0      35863205487
# 69             2.678225             2.743423           0      35863205487
# 70             2.007137             2.118486           0      35863205487
# 71             2.212085             2.414154           0      35863205487
#
#     ms_file_size_MB
# 0         12.731823
# 1         12.731823
# 2         12.731823
# 3         12.731823
# 4         12.731823
# ..              ...
# 67        16.030061
# 68        16.030061
# 69        16.030061
# 70        16.030061
# 71        16.030061
#
# [72 rows x 28 columns]

# %% [markdown]
# # Post processing

# %% [markdown]
# ## Create crosstable of results

# %%
mint.crosstab?
# Out:
# Signature:
# mint.crosstab(
#     var_name: str = None,
#     index: str = None,
#     column: str = None,
#     aggfunc: str = 'mean',
#     apply: Callable = None,
#     scaler: Callable = None,
#     groupby: str = None,
# )
# Docstring:
# Create condensed representation of the results.
# More specifically, a cross-table with filenames as index and target labels.
# The values in the cells are determined by *col_name*.
#
# :param var_name: Name of the column from *mint.results* table that is used for the cell values. If None, defaults to 'peak_area_top3'.
# :type var_name: str, optional
#
# :param index: Name of the column to be used as index in the resulting cross-tabulation. If None, defaults to 'ms_file_label'.
# :type index: str, optional
#
# :param column: Name of the column to be used as columns in the resulting cross-tabulation. If None, defaults to 'peak_label'.
# :type column: str, optional
#
# :param aggfunc: Aggregation function to be used for aggregating values. Defaults to 'mean'.
# :type aggfunc: str, optional
#
# :param apply: Function to be applied to the resulting cross-tabulation. If None, no function is applied.
# :type apply: Callable, optional
#
# :param scaler: Function to scale the data in the resulting cross-tabulation. If None, no scaling is performed.
# :type scaler: Callable, optional
#
# :param groupby: Name of the column to group data before scaling. If None, scaling is applied to the whole data, not group-wise.
# :type groupby: str, optional
#
# :return: DataFrame representing the cross-tabulation.
# :rtype: pandas.DataFrame
# File:      ~/workspace/ms-mint/ms_mint/Mint.py
# Type:      method

# %%
mint.crosstab()
# Out:
# peak_label     Arabitol  Mevalonate  Nicotinate   Succinate  Urocanate  \
# ms_file_label
# CA_B1           51759.0       746.0      8181.0     10653.0     4432.0
# CA_B2           27296.0       768.0     18237.0     10052.0     5676.0
# CA_B3           76728.0      1003.0     21232.0     13645.0     8319.0
# CA_B4          111381.0      1161.0     15178.0     14090.0     8807.0
# EC_B1            1574.0      3034.0    184829.0  71988596.0     8655.0
# EC_B2            1560.0      3411.0    171241.0  22321280.0   222319.0
# EC_B3            2513.0      2871.0    216289.0  59947034.0     8088.0
# EC_B4            1701.0      2442.0    271097.0  55388301.0     5053.0
# SA_B1            3034.0    178965.0     84568.0   1759483.0     4756.0
# SA_B2            3579.0     91528.0     47386.0   2513905.0    76193.0
# SA_B3            3224.0     74213.0     42411.0   3436153.0    14769.0
# SA_B4            3470.0    173750.0     77821.0   1873336.0    29242.0
#
# peak_label     Xanthine
# ms_file_label
# CA_B1          158500.0
# CA_B2          168404.0
# CA_B3          295417.0
# CA_B4          271070.0
# EC_B1            6629.0
# EC_B2            4402.0
# EC_B3            9133.0
# EC_B4            7375.0
# SA_B1            3976.0
# SA_B2            3559.0
# SA_B3            5128.0
# SA_B4            4355.0

# %% [markdown]
# ## Create normalized crosstable

# %%
mint.crosstab()
# Out:
# peak_label     Arabitol  Mevalonate  Nicotinate   Succinate  Urocanate  \
# ms_file_label
# CA_B1           51759.0       746.0      8181.0     10653.0     4432.0
# CA_B2           27296.0       768.0     18237.0     10052.0     5676.0
# CA_B3           76728.0      1003.0     21232.0     13645.0     8319.0
# CA_B4          111381.0      1161.0     15178.0     14090.0     8807.0
# EC_B1            1574.0      3034.0    184829.0  71988596.0     8655.0
# EC_B2            1560.0      3411.0    171241.0  22321280.0   222319.0
# EC_B3            2513.0      2871.0    216289.0  59947034.0     8088.0
# EC_B4            1701.0      2442.0    271097.0  55388301.0     5053.0
# SA_B1            3034.0    178965.0     84568.0   1759483.0     4756.0
# SA_B2            3579.0     91528.0     47386.0   2513905.0    76193.0
# SA_B3            3224.0     74213.0     42411.0   3436153.0    14769.0
# SA_B4            3470.0    173750.0     77821.0   1873336.0    29242.0
#
# peak_label     Xanthine
# ms_file_label
# CA_B1          158500.0
# CA_B2          168404.0
# CA_B3          295417.0
# CA_B4          271070.0
# EC_B1            6629.0
# EC_B2            4402.0
# EC_B3            9133.0
# EC_B4            7375.0
# SA_B1            3976.0
# SA_B2            3559.0
# SA_B3            5128.0
# SA_B4            4355.0

# %% [markdown]
# ## Scaling

# %%
mint.crosstab(scaler='standard').describe()
# Out:
# peak_label      Arabitol    Mevalonate    Nicotinate     Succinate  \
# count       1.200000e+01  1.200000e+01  1.200000e+01  1.200000e+01
# mean       -9.251859e-18 -1.850372e-17 -1.850372e-17 -3.700743e-17
# std         1.044466e+00  1.044466e+00  1.044466e+00  1.044466e+00
# min        -6.369911e-01 -6.620711e-01 -1.018832e+00 -6.919260e-01
# 25%        -6.156870e-01 -6.563880e-01 -8.769781e-01 -6.917772e-01
# 50%        -5.862305e-01 -6.286762e-01 -3.913020e-01 -6.091976e-01
# 75%         2.677740e-01  5.153507e-01  9.005343e-01  4.665754e-01
# max         2.482530e+00  2.035235e+00  2.012774e+00  2.035109e+00
#
# peak_label     Urocanate      Xanthine
# count       1.200000e+01  1.200000e+01
# mean       -4.625929e-18  6.476301e-17
# std         1.044466e+00  1.044466e+00
# min        -4.743549e-01 -6.877637e-01
# 25%        -4.563014e-01 -6.801005e-01
# 50%        -4.070846e-01 -6.560229e-01
# 75%        -2.428448e-01  7.634543e-01
# max         3.140273e+00  2.002858e+00

# %%
mint.crosstab(scaler='robust').plot.box(figsize=(9,3))
# Out:
# <Axes: >

# %% [markdown]
# You can also pass in an instance of a scikit-learn scaler:

# %%
from sklearn.preprocessing import RobustScaler

mint.crosstab( scaler=RobustScaler() ).plot.box(figsize=(9,3))
# Out:
# <Axes: >

# %% [markdown]
# ## Apply transformations before scaling:

# %% [markdown]
# You can pass in a transformation function which is applied before the scaling is applied:

# %%
import numpy as np

mint.crosstab(apply=np.log1p, scaler='standard')
# Out:
# peak_label     Arabitol  Mevalonate  Nicotinate  Succinate  Urocanate  \
# ms_file_label
# CA_B1          1.280895   -1.053003   -1.738165  -1.347101  -0.919901
# CA_B2          0.869371   -1.039191   -1.020514  -1.363969  -0.707996
# CA_B3          1.534084   -0.912300   -0.884384  -1.275194  -0.380527
# CA_B4          1.773783   -0.842753   -1.184888  -1.265871  -0.331697
# EC_B1         -0.965273   -0.385897    1.052949   1.214796  -0.346610
# EC_B2         -0.971016   -0.330181    0.984585   0.874607   2.434159
# EC_B3         -0.664516   -0.412166    1.193676   1.161617  -0.404650
# EC_B4         -0.915396   -0.489151    1.395890   1.138639  -0.807583
# SA_B1         -0.543385    1.554167    0.352938   0.136536  -0.859468
# SA_B2         -0.437165    1.235085   -0.165641   0.240198   1.516763
# SA_B3         -0.504331    1.135296   -0.264945   0.330990   0.111170
# SA_B4         -0.457052    1.540094    0.278499   0.154752   0.696340
#
# peak_label     Xanthine
# ms_file_label
# CA_B1          1.221644
# CA_B2          1.255865
# CA_B3          1.573174
# CA_B4          1.524614
# EC_B1         -0.570447
# EC_B2         -0.801544
# EC_B3         -0.389554
# EC_B4         -0.510247
# SA_B1         -0.858995
# SA_B2         -0.921533
# SA_B3         -0.715374
# SA_B4         -0.807603

# %% [markdown]
# ## Check instrument mass-callibration with crosstab

# %% [markdown]
# For quality control purposes we can plot the values of the `peak_mass_diff_50pc` i.e. the median of the difference between observed data in the extraction window and the `mz_mean` valuein the target list. If the instrument is calibrated well these values should be around 0. The values are relative to the target mass in `ppm`. And since only data in the extraction window is considered the values are between `(-mz_width,mz_width )`. If the calibration is worth than this there will not be any intensity detected for the particular molecular target.

# %%
mint.crosstab('peak_mass_diff_50pc').style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_d6955_row0_col0, #T_d6955_row0_col1, #T_d6955_row1_col5, #T_d6955_row2_col0 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_d6955_row0_col2, #T_d6955_row0_col5, #T_d6955_row1_col1, #T_d6955_row2_col1, #T_d6955_row2_col3, #T_d6955_row3_col0, #T_d6955_row3_col4, #T_d6955_row3_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_d6955_row0_col3, #T_d6955_row3_col3 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_d6955_row0_col4 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_d6955_row1_col0 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_d6955_row1_col2 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_d6955_row1_col3 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_d6955_row1_col4, #T_d6955_row2_col4 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_d6955_row2_col2 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_d6955_row2_col5 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_d6955_row3_col1, #T_d6955_row3_col2 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_d6955_row4_col0, #T_d6955_row4_col1, #T_d6955_row4_col2, #T_d6955_row4_col3, #T_d6955_row4_col4, #T_d6955_row4_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d6955_row5_col0, #T_d6955_row7_col0, #T_d6955_row7_col4, #T_d6955_row8_col4, #T_d6955_row10_col4 {
#   background-color: #9f0e14;
#   color: #f1f1f1;
# }
# #T_d6955_row5_col1 {
#   background-color: #c3161b;
#   color: #f1f1f1;
# }
# #T_d6955_row5_col2, #T_d6955_row7_col2 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_d6955_row5_col3, #T_d6955_row8_col3, #T_d6955_row8_col5 {
#   background-color: #a91016;
#   color: #f1f1f1;
# }
# #T_d6955_row5_col4, #T_d6955_row6_col4 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_d6955_row5_col5, #T_d6955_row6_col5, #T_d6955_row7_col5, #T_d6955_row10_col5 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_d6955_row6_col0, #T_d6955_row6_col3, #T_d6955_row7_col3 {
#   background-color: #8e0912;
#   color: #f1f1f1;
# }
# #T_d6955_row6_col1, #T_d6955_row6_col2, #T_d6955_row10_col0 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_d6955_row7_col1 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_d6955_row8_col0 {
#   background-color: #b61319;
#   color: #f1f1f1;
# }
# #T_d6955_row8_col1, #T_d6955_row10_col1 {
#   background-color: #ce1a1e;
#   color: #f1f1f1;
# }
# #T_d6955_row8_col2, #T_d6955_row11_col2 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# #T_d6955_row9_col0 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_d6955_row9_col1, #T_d6955_row11_col1 {
#   background-color: #d72322;
#   color: #f1f1f1;
# }
# #T_d6955_row9_col2 {
#   background-color: #c2161b;
#   color: #f1f1f1;
# }
# #T_d6955_row9_col3 {
#   background-color: #bb141a;
#   color: #f1f1f1;
# }
# #T_d6955_row9_col4 {
#   background-color: #c5171c;
#   color: #f1f1f1;
# }
# #T_d6955_row9_col5 {
#   background-color: #c8171c;
#   color: #f1f1f1;
# }
# #T_d6955_row10_col2, #T_d6955_row10_col3, #T_d6955_row11_col0 {
#   background-color: #ab1016;
#   color: #f1f1f1;
# }
# #T_d6955_row11_col3 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_d6955_row11_col4 {
#   background-color: #ad1117;
#   color: #f1f1f1;
# }
# #T_d6955_row11_col5 {
#   background-color: #b31218;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d6955">
#   <thead>
#     <tr>
#       <th class="index_name level0" >peak_label</th>
#       <th id="T_d6955_level0_col0" class="col_heading level0 col0" >Arabitol</th>
#       <th id="T_d6955_level0_col1" class="col_heading level0 col1" >Mevalonate</th>
#       <th id="T_d6955_level0_col2" class="col_heading level0 col2" >Nicotinate</th>
#       <th id="T_d6955_level0_col3" class="col_heading level0 col3" >Succinate</th>
#       <th id="T_d6955_level0_col4" class="col_heading level0 col4" >Urocanate</th>
#       <th id="T_d6955_level0_col5" class="col_heading level0 col5" >Xanthine</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ms_file_label</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6955_level0_row0" class="row_heading level0 row0" >CA_B1</th>
#       <td id="T_d6955_row0_col0" class="data row0 col0" >2.532551</td>
#       <td id="T_d6955_row0_col1" class="data row0 col1" >2.104648</td>
#       <td id="T_d6955_row0_col2" class="data row0 col2" >-0.676354</td>
#       <td id="T_d6955_row0_col3" class="data row0 col3" >0.070309</td>
#       <td id="T_d6955_row0_col4" class="data row0 col4" >-0.331197</td>
#       <td id="T_d6955_row0_col5" class="data row0 col5" >-0.212738</td>
#     </tr>
#     <tr>
#       <th id="T_d6955_level0_row1" class="row_heading level0 row1" >CA_B2</th>
#       <td id="T_d6955_row1_col0" class="data row1 col0" >2.633562</td>
#       <td id="T_d6955_row1_col1" class="data row1 col1" >2.000893</td>
#       <td id="T_d6955_row1_col2" class="data row1 col2" >-0.363736</td>
#       <td id="T_d6955_row1_col3" class="data row1 col3" >0.200705</td>
#       <td id="T_d6955_row1_col4" class="data row1 col4" >-0.108499</td>
#       <td id="T_d6955_row1_col5" class="data row1 col5" >-0.111704</td>
#     </tr>
#     <tr>
#       <th id="T_d6955_level0_row2" class="row_heading level0 row2" >CA_B3</th>
#       <td id="T_d6955_row2_col0" class="data row2 col0" >2.532551</td>
#       <td id="T_d6955_row2_col1" class="data row2 col1" >2.000893</td>
#       <td id="T_d6955_row2_col2" class="data row2 col2" >-0.426260</td>
#       <td id="T_d6955_row2_col3" class="data row2 col3" >-0.060086</td>
#       <td id="T_d6955_row2_col4" class="data row2 col4" >-0.108499</td>
#       <td id="T_d6955_row2_col5" class="data row2 col5" >-0.010669</td>
#     </tr>
#     <tr>
#       <th id="T_d6955_level0_row3" class="row_heading level0 row3" >CA_B4</th>
#       <td id="T_d6955_row3_col0" class="data row3 col0" >2.431539</td>
#       <td id="T_d6955_row3_col1" class="data row3 col1" >2.052770</td>
#       <td id="T_d6955_row3_col2" class="data row3 col2" >-0.613830</td>
#       <td id="T_d6955_row3_col3" class="data row3 col3" >0.070309</td>
#       <td id="T_d6955_row3_col4" class="data row3 col4" >-0.442546</td>
#       <td id="T_d6955_row3_col5" class="data row3 col5" >-0.212738</td>
#     </tr>
#     <tr>
#       <th id="T_d6955_level0_row4" class="row_heading level0 row4" >EC_B1</th>
#       <td id="T_d6955_row4_col0" class="data row4 col0" >5.512378</td>
#       <td id="T_d6955_row4_col1" class="data row4 col1" >5.217295</td>
#       <td id="T_d6955_row4_col2" class="data row4 col2" >2.699912</td>
#       <td id="T_d6955_row4_col3" class="data row4 col3" >3.265006</td>
#       <td id="T_d6955_row4_col4" class="data row4 col4" >2.452534</td>
#       <td id="T_d6955_row4_col5" class="data row4 col5" >2.717257</td>
#     </tr>
#     <tr>
#       <th id="T_d6955_level0_row5" class="row_heading level0 row5" >EC_B2</th>
#       <td id="T_d6955_row5_col0" class="data row5 col0" >5.158840</td>
#       <td id="T_d6955_row5_col1" class="data row5 col1" >4.491011</td>
#       <td id="T_d6955_row5_col2" class="data row5 col2" >2.324772</td>
#       <td id="T_d6955_row5_col3" class="data row5 col3" >2.808621</td>
#       <td id="T_d6955_row5_col4" class="data row5 col4" >2.229836</td>
#       <td id="T_d6955_row5_col5" class="data row5 col5" >2.414154</td>
#     </tr>
#     <tr>
#       <th id="T_d6955_level0_row6" class="row_heading level0 row6" >EC_B3</th>
#       <td id="T_d6955_row6_col0" class="data row6 col0" >5.259851</td>
#       <td id="T_d6955_row6_col1" class="data row6 col1" >4.802275</td>
#       <td id="T_d6955_row6_col2" class="data row6 col2" >2.262248</td>
#       <td id="T_d6955_row6_col3" class="data row6 col3" >3.004214</td>
#       <td id="T_d6955_row6_col4" class="data row6 col4" >2.229836</td>
#       <td id="T_d6955_row6_col5" class="data row6 col5" >2.414154</td>
#     </tr>
#     <tr>
#       <th id="T_d6955_level0_row7" class="row_heading level0 row7" >EC_B4</th>
#       <td id="T_d6955_row7_col0" class="data row7 col0" >5.158840</td>
#       <td id="T_d6955_row7

# %%
sns.catplot(data = mint.crosstab('peak_mass_diff_50pc').stack().to_frame().rename(columns={0: 'Mass calibration [ppm]'}).reset_index(), 
            x='ms_file_label', y='Mass calibration [ppm]', kind='violin', height=2.5, aspect=4)
# Out:
# /home/swacker/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# We see that the _Candida_ samples (CA) have a different calibration than the rest of the files. The sets were probably generated at different points in time.

# %%
(mint.crosstab('peak_rt_of_max') - mint.crosstab('rt')).T.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_03e22_row0_col0 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_03e22_row0_col1 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_03e22_row0_col2, #T_03e22_row1_col0, #T_03e22_row1_col1, #T_03e22_row1_col3, #T_03e22_row1_col6, #T_03e22_row1_col7, #T_03e22_row3_col9, #T_03e22_row4_col5, #T_03e22_row4_col8, #T_03e22_row5_col4, #T_03e22_row5_col10, #T_03e22_row5_col11 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_03e22_row0_col3 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_03e22_row0_col4 {
#   background-color: #fc8464;
#   color: #f1f1f1;
# }
# #T_03e22_row0_col5 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_03e22_row0_col6 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_03e22_row0_col7 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_03e22_row0_col8 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_03e22_row0_col9 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_03e22_row0_col10 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_03e22_row0_col11 {
#   background-color: #fca486;
#   color: #000000;
# }
# #T_03e22_row1_col2, #T_03e22_row1_col4, #T_03e22_row1_col8, #T_03e22_row1_col9, #T_03e22_row1_col10, #T_03e22_row1_col11, #T_03e22_row2_col0, #T_03e22_row2_col1, #T_03e22_row2_col5, #T_03e22_row2_col6, #T_03e22_row2_col7, #T_03e22_row5_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_03e22_row1_col5, #T_03e22_row3_col7 {
#   background-color: #de2b25;
#   color: #f1f1f1;
# }
# #T_03e22_row2_col2 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_03e22_row2_col3 {
#   background-color: #840711;
#   color: #f1f1f1;
# }
# #T_03e22_row2_col4 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_03e22_row2_col8 {
#   background-color: #f14331;
#   color: #f1f1f1;
# }
# #T_03e22_row2_col9, #T_03e22_row3_col2 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_03e22_row2_col10 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_03e22_row2_col11 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_03e22_row3_col0 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_03e22_row3_col1 {
#   background-color: #a30f15;
#   color: #f1f1f1;
# }
# #T_03e22_row3_col3 {
#   background-color: #d01d1f;
#   color: #f1f1f1;
# }
# #T_03e22_row3_col4 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_03e22_row3_col5 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_03e22_row3_col6 {
#   background-color: #d72322;
#   color: #f1f1f1;
# }
# #T_03e22_row3_col8 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_03e22_row3_col10, #T_03e22_row4_col0 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_03e22_row3_col11, #T_03e22_row5_col9 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_03e22_row4_col1 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_03e22_row4_col2 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_03e22_row4_col3 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_03e22_row4_col4 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_03e22_row4_col6 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_03e22_row4_col7 {
#   background-color: #fc9777;
#   color: #000000;
# }
# #T_03e22_row4_col9 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_03e22_row4_col10 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_03e22_row4_col11 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_03e22_row5_col0 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_03e22_row5_col1 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_03e22_row5_col2 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_03e22_row5_col5 {
#   background-color: #d82422;
#   color: #f1f1f1;
# }
# #T_03e22_row5_col6 {
#   background-color: #c1161b;
#   color: #f1f1f1;
# }
# #T_03e22_row5_col7 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_03e22_row5_col8 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# </style>
# <table id="T_03e22">
#   <thead>
#     <tr>
#       <th class="index_name level0" >ms_file_label</th>
#       <th id="T_03e22_level0_col0" class="col_heading level0 col0" >CA_B1</th>
#       <th id="T_03e22_level0_col1" class="col_heading level0 col1" >CA_B2</th>
#       <th id="T_03e22_level0_col2" class="col_heading level0 col2" >CA_B3</th>
#       <th id="T_03e22_level0_col3" class="col_heading level0 col3" >CA_B4</th>
#       <th id="T_03e22_level0_col4" class="col_heading level0 col4" >EC_B1</th>
#       <th id="T_03e22_level0_col5" class="col_heading level0 col5" >EC_B2</th>
#       <th id="T_03e22_level0_col6" class="col_heading level0 col6" >EC_B3</th>
#       <th id="T_03e22_level0_col7" class="col_heading level0 col7" >EC_B4</th>
#       <th id="T_03e22_level0_col8" class="col_heading level0 col8" >SA_B1</th>
#       <th id="T_03e22_level0_col9" class="col_heading level0 col9" >SA_B2</th>
#       <th id="T_03e22_level0_col10" class="col_heading level0 col10" >SA_B3</th>
#       <th id="T_03e22_level0_col11" class="col_heading level0 col11" >SA_B4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >peak_label</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03e22_level0_row0" class="row_heading level0 row0" >Arabitol</th>
#       <td id="T_03e22_row0_col0" class="data row0 col0" >-14.946991</td>
#       <td id="T_03e22_row0_col1" class="data row0 col1" >-17.231995</td>
#       <td id="T_03e22_row0_col2" class="data row0 col2" >-13.967987</td>
#       <td id="T_03e22_row0_col3" class="data row0 col3" >-15.734985</td>
#       <td id="T_03e22_row0_col4" class="data row0 col4" >5.322998</td>
#       <td id="T_03e22_row0_col5" class="data row0 col5" >9.131012</td>
#       <td id="T_03e22_row0_col6" class="data row0 col6" >0.658997</td>
#       <td id="T_03e22_row0_col7" class="data row0 col7" >-5.438995</td>
#       <td id="T_03e22_row0_col8" class="data row0 col8" >17.858002</td>
#       <td id="T_03e22_row0_col9" class="data row0 col9" >7.321991</td>
#       <td id="T_03e22_row0_col10" class="data row0 col10" >-17.484985</td>
#       <td id="T_03e22_row0_col11" class="data row0 col11" >3.670013</td>
#     </tr>
#     <tr>
#       <th id="T_03e22_level0_row1" class="row_heading level0 row1" >Mevalonate</th>
#       <td id="T_03e22_row1_col0" class="data row1 col0" >-46.311005</td>
#       <td id="T_03e22_row1_col1" class="data row1 col1" >-77.529999</td>
#       <td id="T_03e22_row1_col2" class="data row1 col2" >52.537003</td>
#       <td id="T_03e22_row1_col3" class="data row1 col3" >-54.771004</td>
#       <td id="T_03e22_row1_col4" class="data row1 col4" >48.440994</td>
#       <td id="T_03e22_row1_col5" class="data row1 col5" >23.897003</td>
#       <td id="T_03e22_row1_col6" class="data row1 col6" >-69.011002</td>
#       <td id="T_03e22_row1_col7" class="data row1 col7" >-43.735992</td>
#       <td id="T_03e22_row1_col8" class="data row1 col8" >73.052002</td>
#       <td id="T_03e22_row1_col9" class="data row1 col9" >71.522995</td>
#       <td id="T_03e22_row1_col10" class="data row1 col10" >82.601013</td>
#       <td id="T_03e22_row1_col11" class="data row1 col11" >85.354004</td>
#     </tr>
#     <tr>
#       <th id="T_03e22_level0_row2" class="row_heading level0 row2" >Nicotinate</th>
#       <td id="T_03e22_row2_col0" class="data row2 col0" >43.342005</td>
#       <td id="T_03e22_row2_col1" class="data row2 col1" >40.648005</td>
#       <td id="T_03e22_row2_col2" class="data row2 col2" >37.374995</td>
#       <td id="T_03e22_row2_col3" class="data row2 col3" >28.713007</td>
#       <td id="T_03e22_row2_col4" class="data row2 col4" >-11.508993</td>
#       <td id="T_03e22_row2_col5" class="data row2 col5" >41.113001</td>
#       <td id="T_03e22_row2_col6" class="data row2 col6" >39.984995</td>
#       <td id="T

# %%
mint.plot.peak_shapes(col_wrap=6, height=2)
# Out:
# /home/swacker/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
mint.results['rt_diff [s]'] = mint.results.peak_rt_of_max - mint.results.rt
g = sns.relplot(data=mint.results, x='rt_diff [s]', y='peak_max', style='ms_file', hue='peak_label', s=50)
g.set(yscale='log')
plt.title('Retention time drift')
# Out:
# /home/swacker/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Retention time drift')

# %%
mint.plot.chromatogram()
# Out:
# Loading chromatograms:   0%|          | 0/12 [00:00<?, ?it/s]
# /home/swacker/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Fitlers can be applied to smoothen the chromatograms

# %%
from ms_mint.filters import GaussFilter, Resampler, Smoother
mint.plot.chromatogram(filters=[Resampler(), GaussFilter()])
# Out:
# Loading chromatograms:   0%|          | 0/12 [00:00<?, ?it/s]
# /home/swacker/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Run Peak optimization

# %% [markdown]
# The peak optimization should be run using standards samples with a well defined concentration of the target metabolite to ensure the right peak is detected. Usually, expert knowledge is required in order to select the correct peak.

# %%
mint.opt.rt_min_max(plot=True, sigma=200, rel_height=0.9)
# Out:
# Reading files:   0%|          | 0/12 [00:00<?, ?it/s]
# Optimizing targets:   0%|          | 0/6 [00:00<?, ?it/s]
# Set targets to:
#                mz_mean  mz_width       rt      rt_min      rt_max rt_unit  intensity_threshold target_filename
# peak_label
# Arabitol    151.06050        10  295.500  263.499600  316.501395       s                    0     targets.csv
# Mevalonate  147.06570        10  180.000  104.516092  218.511542       s                    0     targets.csv
# Nicotinate  122.02455        10  183.204  170.221100  207.740921       s                    0     targets.csv
# Succinate   117.01905        10  122.634  108.665464  135.213196       s                    0     targets.csv
# Urocanate   137.03540        10  264.900  253.577696  276.065473       s                    0     targets.csv
# Xanthine    151.02585        10  250.000  207.914503  251.344215       s                    0     targets.csv
# (<ms_mint.notebook.Mint at 0x7f41fb6869b0>, <Figure size 1800x600 with 6 Axes>)

# %% [markdown]
# The blue bar in this plot is the `rt` value given in the target list. The green dotted bar is the Gaussian weight that is applied to the data to select the correct peak. Sometimes, there is no one setting that works for all peaks simultaneously. Therefore, the peaks can be specified with the `peak_label` argument. For example:
#
#     mint.opt.rt_min_max(plot=True, sigma=200, rel_height=0.7, peak_label=['Arabitol'])

# %% [markdown]
# When the retention time range are optimized the data extraction process has to be repeated to update the results dataframe.

# %%
mint.opt.rt_min_max(plot=True, sigma=200, rel_height=0.7, peak_labels=['Arabitol'])
# Out:
# Reading files:   0%|          | 0/12 [00:00<?, ?it/s]
# Optimizing targets:   0%|          | 0/6 [00:00<?, ?it/s]
# WARNING:root:Mevalonate not in ['Arabitol']
# WARNING:root:Nicotinate not in ['Arabitol']
# WARNING:root:Succinate not in ['Arabitol']
# WARNING:root:Urocanate not in ['Arabitol']
# WARNING:root:Xanthine not in ['Arabitol']
# Set targets to:
#                mz_mean  mz_width       rt      rt_min      rt_max rt_unit  intensity_threshold target_filename
# peak_label
# Arabitol    151.06050        10  295.500  277.136620  298.961208       s                    0     targets.csv
# Mevalonate  147.06570        10  180.000  104.516092  218.511542       s                    0     targets.csv
# Nicotinate  122.02455        10  183.204  170.221100  207.740921       s                    0     targets.csv
# Succinate   117.01905        10  122.634  108.665464  135.213196       s                    0     targets.csv
# Urocanate   137.03540        10  264.900  253.577696  276.065473       s                    0     targets.csv
# Xanthine    151.02585        10  250.000  207.914503  251.344215       s                    0     targets.csv
# (<ms_mint.notebook.Mint at 0x7f41fb6869b0>, <Figure size 1800x300 with 1 Axes>)

# %%
mint.targets
# Out:
#               mz_mean  mz_width       rt      rt_min      rt_max rt_unit  \
# peak_label
# Arabitol    151.06050        10  295.500  277.136620  298.961208       s
# Mevalonate  147.06570        10  180.000  104.516092  218.511542       s
# Nicotinate  122.02455        10  183.204  170.221100  207.740921       s
# Succinate   117.01905        10  122.634  108.665464  135.213196       s
# Urocanate   137.03540        10  264.900  253.577696  276.065473       s
# Xanthine    151.02585        10  250.000  207.914503  251.344215       s
#
#             intensity_threshold target_filename
# peak_label
# Arabitol                      0     targets.csv
# Mevalonate                    0     targets.csv
# Nicotinate                    0     targets.csv
# Succinate                     0     targets.csv
# Urocanate                     0     targets.csv
# Xanthine                      0     targets.csv

# %%
mint.run()
# Out:
# Run MINT with 12 processes:
# Total runtime: 3.35s
# Runtime per file: 0.28s
# Runtime per peak (6): 0.05s
#
# Results:                                               ms_file ms_file_label  \
# 0   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 1   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 2   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 3   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 4   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# ..                                                ...           ...
# 67  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 68  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 69  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 70  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 71  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
#
#     peak_label    mz_mean  mz_width       rt      rt_min      rt_max rt_unit  \
# 0     Arabitol  151.06050        10  295.500  277.136620  298.961208       s
# 1   Mevalonate  147.06570        10  180.000  104.516092  218.511542       s
# 2   Nicotinate  122.02455        10  183.204  170.221100  207.740921       s
# 3    Succinate  117.01905        10  122.634  108.665464  135.213196       s
# 4    Urocanate  137.03540        10  264.900  253.577696  276.065473       s
# ..         ...        ...       ...      ...         ...         ...     ...
# 67  Mevalonate  147.06570        10  180.000  104.516092  218.511542       s
# 68  Nicotinate  122.02455        10  183.204  170.221100  207.740921       s
# 69   Succinate  117.01905        10  122.634  108.665464  135.213196       s
# 70   Urocanate  137.03540        10  264.900  253.577696  276.065473       s
# 71    Xanthine  151.02585        10  250.000  207.914503  251.344215       s
#
#     intensity_threshold  ...     peak_mean  peak_delta_int  \
# 0                     0  ...  3.239715e+04         21800.0
# 1                     0  ...  5.137619e+02            71.0
# 2                     0  ...  3.808675e+03            12.0
# 3                     0  ...  8.214417e+04        642827.0
# 4                     0  ...  2.033167e+03            87.0
# ..                  ...  ...           ...             ...
# 67                    0  ...  7.302610e+04          7030.0
# 68                    0  ...  3.628137e+04          2133.0
# 69                    0  ...  1.511406e+06        167871.0
# 70                    0  ...  8.340000e+03            46.0
# 71                    0  ...  2.363423e+03          3091.0
#
#                                         peak_shape_rt  \
# 0   277.81,278.51,279.18,279.86,280.55,281.25,281....
# 1   105.63,106.39,114.73,115.49,123.83,125.35,127....
# 2   173.88,176.91,178.43,179.18,179.94,180.7,181.4...
# 3   108.67,109.43,110.18,110.94,111.7,112.46,113.2...
# 4   255.36,256.12,256.88,257.64,258.39,259.15,259....
# ..                                                ...
# 67  104.53,105.29,106.05,106.81,107.57,108.32,109....
# 68  171.26,172.02,172.77,173.53,174.29,175.05,175....
# 69  109.08,109.84,110.6,111.36,112.12,112.87,113.6...
# 70  254.24,254.98,256.46,257.19,257.93,258.67,259....
# 71  208.19,208.9,209.61,210.32,211.03,211.74,212.4...
#
#                                        peak_shape_int  peak_mass_diff_25pc  \
# 0   2798,5192,6006,9870,14188,20467,35327,41981,46...             2.330528
# 1   333,377,475,479,444,428,548,562,721,511,1240,4...             1.689628
# 2   647,811,698,455,1794,2279,3196,2557,3740,4891,...            -0.801400
# 3   649254,561301,434958,286148,189184,144502,1029...             0.200705
# 4   661,543,933,747,451,911,869,2694,5126,4307,491...            -0.693082
# ..                                                ...                  ...
# 67  7104,7598,10937,22360,25050,35087,50476,62345,...             4.179746
# 68  2091,3105,4858,7611,12579,15085,23960,29448,42...             2.074678
# 69  10678,25255,61762,159739,294352,504985,832045,...             2.678225
# 70  952,873,561,634,982,1766,1006,1997,4815,8260,1...             1.784439
# 71  3807,4755,4504,4662,3813,3681,2260,614,665,133...             2.111051
#
#     peak_mass_diff_50pc  peak_mass_diff_75pc  peak_score  total_intensity  \
# 0              2.532551             2.633562           0      25525758921
# 1              2.104648             2.208403           0      25525758921
# 2             -0.676354            -0.488783           0      25525758921
# 3              0.265903             0.265903           0      25525758921
# 4             -0.331197            -0.108499           0      25525758921
# ..                  ...                  ...         ...              ...
# 67             4.283501             4.387256           0      35863205487
# 68             2.137201             2.199725           0      35863205487
# 69             2.743423             2.808621           0      35863205487
# 70             2.007137             2.118486           0      35863205487
# 71             2.313119             2.540447           0      35863205487
#
#     ms_file_size_MB
# 0         12.731823
# 1         12.731823
# 2         12.731823
# 3         12.731823
# 4         12.731823
# ..              ...
# 67        16.030061
# 68        16.030061
# 69        16.030061
# 70        16.030061
# 71        16.030061
#
# [72 rows x 28 columns]

# %%
mint.plot.peak_shapes()
# Out:
# /home/swacker/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Save and load

# %% [markdown]
# ## Save results

# %%
mint.export('input/results.parquet')
mint.save_metadata()

# %% [markdown]
# ## Load results

# %%
mint = Mint()
mint.load('input/results.parquet')

# %%
mint.results
# Out:
#                                               ms_file ms_file_label  \
# 0   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 1   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 2   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 3   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# 4   /data/Metabolomics/ms-mint/230508__ms-mint-dem...         CA_B1
# ..                                                ...           ...
# 67  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 68  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 69  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 70  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
# 71  /data/Metabolomics/ms-mint/230508__ms-mint-dem...         SA_B4
#
#     peak_label    mz_mean  mz_width       rt      rt_min      rt_max rt_unit  \
# 0     Arabitol  151.06050        10  295.500  277.136620  298.961208       s
# 1   Mevalonate  147.06570        10  180.000  104.516092  218.511542       s
# 2   Nicotinate  122.02455        10  183.204  170.221100  207.740921       s
# 3    Succinate  117.01905        10  122.634  108.665464  135.213196       s
# 4    Urocanate  137.03540        10  264.900  253.577696  276.065473       s
# ..         ...        ...       ...      ...         ...         ...     ...
# 67  Mevalonate  147.06570        10  180.000  104.516092  218.511542       s
# 68  Nicotinate  122.02455        10  183.204  170.221100  207.740921       s
# 69   Succinate  117.01905        10  122.634  108.665464  135.213196       s
# 70   Urocanate  137.03540        10  264.900  253.577696  276.065473       s
# 71    Xanthine  151.02585        10  250.000  207.914503  251.344215       s
#
#     intensity_threshold  ...     peak_mean  peak_delta_int  \
# 0                     0  ...  3.239715e+04         21800.0
# 1                     0  ...  5.137619e+02            71.0
# 2                     0  ...  3.808675e+03            12.0
# 3                     0  ...  8.214417e+04        642827.0
# 4                     0  ...  2.033167e+03            87.0
# ..                  ...  ...           ...             ...
# 67                    0  ...  7.302610e+04          7030.0
# 68                    0  ...  3.628137e+04          2133.0
# 69                    0  ...  1.511406e+06        167871.0
# 70                    0  ...  8.340000e+03            46.0
# 71                    0  ...  2.363423e+03          3091.0
#
#                                         peak_shape_rt  \
# 0   277.81,278.51,279.18,279.86,280.55,281.25,281....
# 1   105.63,106.39,114.73,115.49,123.83,125.35,127....
# 2   173.88,176.91,178.43,179.18,179.94,180.7,181.4...
# 3   108.67,109.43,110.18,110.94,111.7,112.46,113.2...
# 4   255.36,256.12,256.88,257.64,258.39,259.15,259....
# ..                                                ...
# 67  104.53,105.29,106.05,106.81,107.57,108.32,109....
# 68  171.26,172.02,172.77,173.53,174.29,175.05,175....
# 69  109.08,109.84,110.6,111.36,112.12,112.87,113.6...
# 70  254.24,254.98,256.46,257.19,257.93,258.67,259....
# 71  208.19,208.9,209.61,210.32,211.03,211.74,212.4...
#
#                                        peak_shape_int  peak_mass_diff_25pc  \
# 0   2798,5192,6006,9870,14188,20467,35327,41981,46...             2.330528
# 1   333,377,475,479,444,428,548,562,721,511,1240,4...             1.689628
# 2   647,811,698,455,1794,2279,3196,2557,3740,4891,...            -0.801400
# 3   649254,561301,434958,286148,189184,144502,1029...             0.200705
# 4   661,543,933,747,451,911,869,2694,5126,4307,491...            -0.693082
# ..                                                ...                  ...
# 67  7104,7598,10937,22360,25050,35087,50476,62345,...             4.179746
# 68  2091,3105,4858,7611,12579,15085,23960,29448,42...             2.074678
# 69  10678,25255,61762,159739,294352,504985,832045,...             2.678225
# 70  952,873,561,634,982,1766,1006,1997,4815,8260,1...             1.784439
# 71  3807,4755,4504,4662,3813,3681,2260,614,665,133...             2.111051
#
#     peak_mass_diff_50pc  peak_mass_diff_75pc  peak_score  total_intensity  \
# 0              2.532551             2.633562    0.070481      25525758921
# 1              2.104648             2.208403    0.025570      25525758921
# 2             -0.676354            -0.488783    0.089177      25525758921
# 3              0.265903             0.265903    0.001401      25525758921
# 4             -0.331197            -0.108499    0.225592      25525758921
# ..                  ...                  ...         ...              ...
# 67             4.283501             4.387256    0.022876      35863205487
# 68             2.137201             2.199725    0.069184      35863205487
# 69             2.743423             2.808621    0.067825      35863205487
# 70             2.007137             2.118486    0.078028      35863205487
# 71             2.313119             2.540447    0.021532      35863205487
#
#     ms_file_size_MB
# 0         12.731823
# 1         12.731823
# 2         12.731823
# 3         12.731823
# 4         12.731823
# ..              ...
# 67        16.030061
# 68        16.030061
# 69        16.030061
# 70        16.030061
# 71        16.030061
#
# [72 rows x 28 columns]

# %%
mint.ms_files
# Out:
# ['/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/CA_B1.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/CA_B2.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/CA_B3.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/CA_B4.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/EC_B1.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/EC_B2.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/EC_B3.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/EC_B4.mzXML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/SA_B1.mzML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/SA_B2.mzML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/SA_B3.mzML',
#  '/data/Metabolomics/ms-mint/230508__ms-mint-demofiles/ms-files/SA_B4.mzML']

# %%
mint.meta
# Out:
#               ms_file label group type run_order plate plate_row plate_col
# ms_file_label
# CA_B1             NaN   NaN   NaN  NaN       NaN   NaN       NaN       NaN
# CA_B2             NaN   NaN   NaN  NaN       NaN   NaN       NaN       NaN
# CA_B3             NaN   NaN   NaN  NaN       NaN   NaN       NaN       NaN
# CA_B4             NaN   NaN   NaN  NaN       NaN   NaN       NaN       NaN
# EC_B1             NaN   NaN   NaN  NaN       NaN   NaN       NaN       NaN
# EC_B2             NaN   NaN   NaN  NaN       NaN   NaN       NaN       NaN
# EC_B3             NaN   NaN   NaN  NaN       NaN   NaN       NaN       NaN
# EC_B4             NaN   NaN   NaN  NaN       NaN   NaN       NaN       NaN
# SA_B1             NaN   NaN   NaN  NaN       NaN   NaN       NaN       NaN
# SA_B2             NaN   NaN   NaN  NaN       NaN   NaN       NaN       NaN
# SA_B3             NaN   NaN   NaN  NaN       NaN   NaN       NaN       NaN
# SA_B4             NaN   NaN   NaN  NaN       NaN   NaN       NaN       NaN

# %%
mint.meta['label'] = [e.split('_')[0] for e in mint.meta.index]

# %% [markdown]
# ## Load metadata

# %%
mint.load_metadata('input/metadata.parquet')

# %%
mint.meta
# Out:
#               ms_file label group  type run_order plate plate_row plate_col
# ms_file_label
# CA_B1            None    CA  None  None      None     1      None      None
# CA_B2            None    CA  None  None      None     2      None      None
# CA_B3            None    CA  None  None      None     3      None      None
# CA_B4            None    CA  None  None      None     4      None      None
# EC_B1            None    EC  None  None      None     1      None      None
# EC_B2            None    EC  None  None      None     2      None      None
# EC_B3            None    EC  None  None      None     3      None      None
# EC_B4            None    EC  None  None      None     4      None      None
# SA_B1            None    SA  None  None      None     1      None      None
# SA_B2            None    SA  None  None      None     2      None      None
# SA_B3            None    SA  None  None      None     3      None      None
# SA_B4            None    SA  None  None      None     4      None      None
